# %%
#List files in default data folder
#dbutils.fs.head("dbfs:/FileStore/tables/testmax_meta_config.lkp")
dbutils.fs.ls("dbfs:/FileStore/tables/")
# Out:
# Out[1]: [FileInfo(path='dbfs:/FileStore/tables/Iris.csv', name='Iris.csv', size=4604, modificationTime=1590245232000),
#  FileInfo(path='dbfs:/FileStore/tables/Pipeline_implementation_task_for_the_Data_Engineer_role.pdf', name='Pipeline_implementation_task_for_the_Data_Engineer_role.pdf', size=73543, modificationTime=1619382887000),
#  FileInfo(path='dbfs:/FileStore/tables/pageviews_by_second_example.tsv', name='pageviews_by_second_example.tsv', size=3663, modificationTime=1606060540000),
#  FileInfo(path='dbfs:/FileStore/tables/testmax_meta_config.lkp', name='testmax_meta_config.lkp', size=1584, modificationTime=1648150219000),
#  FileInfo(path='dbfs:/FileStore/tables/tstmax_tstdfi_20220301_20220301154848', name='tstmax_tstdfi_20220301_20220301154848', size=770, modificationTime=1648137081000)]

# %%
#Create lookup dir
dbutils.fs.mkdirs("dbfs:/mnt/shareddisk/data/lookup/")
#copy file to lookup dir
dbutils.fs.cp("dbfs:/FileStore/tables/testmax_meta_config.lkp","dbfs:/mnt/shareddisk/data/lookup/")
# Out:
# Out[62]: True

# %%
#Create landing dir
dbutils.fs.mkdirs("dbfs:/mnt/shareddisk/data/test/testmax")
#copy file to landing dir
dbutils.fs.cp("dbfs:/FileStore/tables/tstmax_tstdfi_20220301_20220301154848","dbfs:/mnt/shareddisk/data/test/testmax/testmax_tstdfi_20220301_20220301154848")
# Out:
# Out[63]: True
